# %% [markdown]
# <a href="https://colab.research.google.com/github/Madlhawa/Hotel-Recommendation-System/blob/master/Sentiment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Imports

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.tag import pos_tag
from nltk.stem.wordnet import WordNetLemmatizer
import re, string
from nltk.corpus import stopwords
from nltk import FreqDist
import random
from nltk import classify
from nltk import NaiveBayesClassifier
from nltk.tokenize import word_tokenize
import pandas as pd

# %% [markdown]
# # Functions

# %%
def lemmatize_sentence(tokens):
    lemmatizer = WordNetLemmatizer()
    lemmatized_sentence = []
    for word, tag in pos_tag(tokens):
        if tag.startswith('NN'):
            pos = 'n'
        elif tag.startswith('VB'):
            pos = 'v'
        else:
            pos = 'a'
        lemmatized_sentence.append(lemmatizer.lemmatize(word, pos))
    return lemmatized_sentence

# %%
def remove_noise(tweet_tokens, stop_words = ()):

    cleaned_tokens = []

    for token, tag in pos_tag(tweet_tokens):
        token = re.sub('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+#]|[!*\(\),]|'\
                       '(?:%[0-9a-fA-F][0-9a-fA-F]))+','', token)
        token = re.sub("(@[A-Za-z0-9_]+)","", token)

        if tag.startswith("NN"):
            pos = 'n'
        elif tag.startswith('VB'):
            pos = 'v'
        else:
            pos = 'a'

        lemmatizer = WordNetLemmatizer()
        token = lemmatizer.lemmatize(token, pos)

        if len(token) > 0 and token not in string.punctuation and token.lower() not in stop_words:
            cleaned_tokens.append(token.lower())
    return cleaned_tokens

# %%
def get_all_words(cleaned_tokens_list):
    for tokens in cleaned_tokens_list:
        for token in tokens:
            yield token

# %%
def get_reviews_for_model(cleaned_tokens_list):
    for tweet_tokens in cleaned_tokens_list:
        yield dict([token, True] for token in tweet_tokens)

# %% [markdown]
# # Main Code

# %% [markdown]
# ## Two Class

# %%
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Data/booking.csv")

negative = data[(data['rating']<=5)]['review_content'].dropna().tolist()[:500]
positive = data[(data['rating']>5)]['review_content'].dropna().tolist()[:500]

negative_tokens = [word_tokenize(text) for text in negative]
positive_tokens = [word_tokenize(text) for text in positive]

# %%
positive_cleaned_tokens_list = []
negative_cleaned_tokens_list = []

for tokens in positive_tokens:
    positive_cleaned_tokens_list.append(remove_noise(tokens, stopwords.words('english')))

for tokens in negative_tokens:
    negative_cleaned_tokens_list.append(remove_noise(tokens, stopwords.words('english')))

# %%
all_pos_words = get_all_words(positive_cleaned_tokens_list)
freq_dist_pos = FreqDist(all_pos_words)

positive_tokens_for_model = get_reviews_for_model(positive_cleaned_tokens_list)
negative_tokens_for_model = get_reviews_for_model(negative_cleaned_tokens_list)

# %%
positive_dataset = [(review_dict, "Positive")
                     for review_dict in positive_tokens_for_model]

negative_dataset = [(review_dict, "Negative")
                     for review_dict in negative_tokens_for_model]

dataset = positive_dataset + negative_dataset

random.shuffle(dataset)

train_data = dataset[:700]
test_data = dataset[700:]

print(train_data)
# Out:
# [({'view': True, 'breakfast': True, 'proximity': True, 'beach': True, 'shower': True, 'bathroom': True, 'condition': True, 'time': True, 'pool': True, 'close': True, 'way': True, 'early': True, 'heat': True, 'bed': True, 'comfortable': True, 'staff': True, 'checking': True, 'hospitable': True}, 'Negative'), ({'location': True, 'spacious': True, 'hotel': True, 'premise': True, 'nice': True, 'would': True, 'perfect': True, 'stay': True, 'staff': True, 'pay': True, 'attention': True, 'care': True, 'cleanliness': True, 'specially': True, 'din': True, 'area': True, 'restaurant': True, 'rooms': True, 'properly': True, 'clean': True, 'floor': True, 'dust': True, 'take': True, 'time': True, 'world': True, 'serve': True, 'us': True, 'morning': True, 'tea': True, 'despite': True, 'ask': True, 'make': True, 'fast': True}, 'Negative'), ({'side': True, 'location': True, 'bad': True, 'like': True, 'village': True, 'room': True, 'small': True, 'stay': True, 'didnt': True, 'fund': True, 'pool': True, 'ask': True, 'everyday': True, 'staff': True, 'say': True, 'show': True}, 'Negative'), ({'nothing': True, 'surprising': True, 'list': True, 'booking.com': True, 'first': True, 'place': True, 'everything': True, '’': True, 'hotel': True, 'spa': True, 'like': True, 'servant': True, 'quarter': True}, 'Negative'), ({'like': True, 'much': True, 'view': True, 'room': True, 'perfect': True, 'toilet': True, 'clean': True, 'birdwatching': True, 'cooking': True, 'class': True, 'staff': True, 'really': True, 'kind': True, "n't": True, 'think': True, 'say': True, 'something': True, 'far': True}, 'Positive'), ({'noisy': True, 'smell': True, 'hall': True, 'tiny': True, 'room': True, 'little': True, 'space': True, 'move': True, 'around': True}, 'Negative'), ({'location': True, 'good': True, 'near': True, 'sigiriya': True, 'rock': True, 'new': True, 'property': True, '4': True, 'big': True, 'family': True, 'size': True, 'room': True, 'hotel': True, 'also': True, 'swim': True, 'pool': True, 'facility': True, 'staff': True, 'helpful': True, 'courteous': True, 'special': True, 'gesture': True, '31st': True, 'dec': True, 'arrange': True, 'complimentry': True, 'dinner': True, 'guest': True, 'tea': True, 'coffee': True, 'maker': True}, 'Positive'), ({'best': True, 'view': True, 'earth': True, 'come': True, 'nature': True, 'scenery': True, 'friendly': True, 'staff': True, 'good': True, 'food': True, 'clean': True, 'room': True, 'management': True, 'mr': True, 'ganeshwaram': True, 'thennakon': True, 'helpful': True, 'regard': True, 'issue': True, 'service': True}, 'Positive'), ({'’': True, 'sad': True, 'say': True, 'hotel': True, 'room': True, 'expectation': True}, 'Negative'), ({'located': True, 'scenic': True, 'environment': True, 'stay': True, 'room': True, 'overlook': True, 'river': True, 'staff': True, 'friendly': True, 'upgraded': True, 'garden': True, 'view': True, 'free': True, 'able': True, 'see': True, 'lot': True, 'elephant': True, 'book': True, 'hb': True, 'well': True, 'clean': True, 'swimming': True, 'pool': True, 'also': True, 'dirty': True, 'mixed': True, 'rice': True, 'dinner': True, 'use': True, 'msg': True, 'noodle': True, 'available': True, 'choose': True, 'dessert': True, 'serve': True, 'breakfast': True, 'good': True, 'either': True, 'half': True, 'ripe': True, 'melon': True, 'fruit': True, 'tea': True, 'cup': True, 'internet': True}, 'Negative'), ({'couple': True, 'power': True, 'cut': True, 'area': True, 'staff': True, 'go': True, 'way': True, 'provide': True, 'us': True, 'candlelit': True, 'dinner': True, 'bed': True, 'really': True, 'comfortable': True, 'shower': True, 'good': True, 'pool': True, 'lovely': True, 'nice': True, 'close': True, 'bar': True, 'restaurant': True, 'want': True, 'venture': True, 'breakfast': True, 'lunch': True, 'great': True, 'il': True, 'frangipane': True, 'nothing': True}, 'Positive'), ({'everything': True, 'idyllic': True, 'peaceful': True, 'hotel': True, 'thankyou': True, 'nothing': True}, 'Positive'), ({'hotel': T ...

# %%
classifier = NaiveBayesClassifier.train(train_data)

print("Accuracy is:", classify.accuracy(classifier, test_data))

print(classifier.show_most_informative_features(10))
# Out:
# Accuracy is: 0.8366666666666667
# Most Informative Features
#                      bit = True           Positi : Negati =     15.3 : 1.0
#                  jacuzzi = True           Positi : Negati =     14.6 : 1.0
#                    dirty = True           Negati : Positi =     12.8 : 1.0
#                    never = True           Negati : Positi =     12.8 : 1.0
#                fantastic = True           Positi : Negati =     12.5 : 1.0
#                 sigiriya = True           Positi : Negati =     11.6 : 1.0
#                    order = True           Negati : Positi =     10.8 : 1.0
#                     desk = True           Negati : Positi =      9.5 : 1.0
#                   toilet = True           Negati : Positi =      9.5 : 1.0
#                  perfect = True           Positi : Negati =      9.2 : 1.0
# None

# %% [markdown]
# ## Three Class

# %% [markdown]
# ### Multiple Code Blocks

# %%
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Data/booking.csv")

negative = data[(data['rating']<=2)]['review_content'].dropna().tolist()[:3333]
neutral = data[(data['rating']>2) & (data['rating']<=6)]['review_content'].dropna().tolist()[:3333]
positive = data[(data['rating']>6)]['review_content'].dropna().tolist()[:3333]

negative_tokens = [word_tokenize(text) for text in negative]
neutral_tokans = [word_tokenize(text) for text in neutral]
positive_tokens = [word_tokenize(text) for text in positive]

# %%
positive_cleaned_tokens_list = []
neutral_cleaned_tokens_list = []
negative_cleaned_tokens_list = []

for tokens in positive_tokens:
    positive_cleaned_tokens_list.append(remove_noise(tokens, stopwords.words('english')))

for tokens in neutral_tokans:
    neutral_cleaned_tokens_list.append(remove_noise(tokens, stopwords.words('english')))

for tokens in negative_tokens:
    negative_cleaned_tokens_list.append(remove_noise(tokens, stopwords.words('english')))

# %%
all_pos_words = get_all_words(positive_cleaned_tokens_list)
freq_dist_pos = FreqDist(all_pos_words)

positive_tokens_for_model = get_reviews_for_model(positive_cleaned_tokens_list)
neutral_tokens_for_model = get_reviews_for_model(neutral_cleaned_tokens_list)
negative_tokens_for_model = get_reviews_for_model(negative_cleaned_tokens_list)

# %%
positive_dataset = [(review_dict, "Positive")
                     for review_dict in positive_tokens_for_model]

neutral_dataset = [(review_dict, "Neutral")
                     for review_dict in neutral_tokens_for_model]

negative_dataset = [(review_dict, "Negative")
                     for review_dict in negative_tokens_for_model]

dataset = positive_dataset + negative_dataset + neutral_dataset

random.shuffle(dataset)

train_data = dataset[:7000]
test_data = dataset[7000:]

print(train_data)
# Out:
# [({'felt': True, 'like': True, 'secluded': True, 'little': True, 'gem': True, 'quiet': True, 'quaint': True, 'almost': True, 'spirtual': True}, 'Positive'), ({'everything': True, 'best': True, 'place': True, 'sri': True, 'lanka': True, '´': True, 'great': True, 'choice': True, 'swam': True, 'turtle': True, 'acesible': True, 'walkingto': True, 'silent': True, 'beach': True, 'paradise': True, 'food': True, 'pace': True, 'enooooormous': True, 'bed': True, 'super': True, 'confortable': True, 'amenity': True, 'top': True, 'experience': True, 'spending': True, '3': True, 'night': True, 'next': True, 'time': True, 'stay': True, 'one': True, 'entire': True, 'week': True}, 'Positive'), ({'like': True, 'anything': True, 'poor': True, 'water': True, 'empugh': True, 'breakfsat': True, 'recpmmending': True, 'place': True, 'anybody': True, 'book': True, '2': True, 'day': True, 'check': True, 'one': True, 'booking': True, 'confirmation': True, 'say': True, 'price': True, 'proce': True, 'hot': True, 'shower': True, 'morning': True, 'bathroom': True, 'smelly': True, 'wi': True, 'fi': True, 'connect': True, 'peoperley': True, 'dining': True, 'room': True, 'leak': True, 'ceiling': True, 'toast': True, 'roti': True, 'sv': True, 'asilable': True, 'breakfast': True, 'dissapointed': True}, 'Neutral'), ({'great': True, 'location': True, 'walk': True, 'distance': True, 'train': True, 'station': True, 'quick': True, 'main': True, 'street': True, 'bar': True, 'restaurant': True, 'charge': True, 'twice': True, 'price': True, 'state': True, 'booking': True, 'response': True, 'hotel': True, 'bookings.com': True, 'shower': True, 'weak': True, 'pressure': True, 'wifi': True, '’': True, 'work': True, 'room': True, 'also': True, 'furniture': True, 'cover': True, 'ant': True}, 'Neutral'), ({'friendly': True, 'staff': True, 'dinner': True, 'buffet': True, 'awful': True}, 'Neutral'), ({'heaven': True, 'earth': True, 'love': True, 'sri': True, 'lanka': True, 'architecrture': True, 'geffrey': True, 'bawa': True, 'leave': True}, 'Positive'), ({'nice': True, 'small': True, 'property': True, 'good': True, 'location': True, 'value': True, 'money': True, 'entire': True, 'staff': True, 'friendly': True, 'helpful': True, 'breakfast': True, 'fresh': True, 'nothing': True}, 'Positive'), ({'staff': True, 'friendly': True, 'food': True, 'ok': True, 'less': True, 'option': True, 'cleanliness': True, 'cafeteria': True, 'poor': True, 'per': True, 'booking.com': True, 'rate': True, 'usd': True, '90': True, 'hotel': True, 'charge': True, '109': True}, 'Neutral'), ({'friendly': True, 'accomodating': True, 'staff': True, 'excellent': True, 'chef': True, 'pick': True, 'train': True, 'station': True, 'greatly': True, 'appreciate': True, 'spacious': True, 'room': True, 'everything': True, 'need': True, 'hand': True, 'town': True, 'away': True, 'hustle': True, 'bustle': True, 'hatton': True, 'gorgeous': True, 'view': True, 'tea': True, 'plantation': True, 'access': True, 'onsite': True, 'aromatherapy': True, 'massage': True, 'great': True, 'walk': True, 'adams': True, 'peak': True, 'rooms': True, 'little': True, 'tired': True}, 'Positive'), ({'absolutely': True, 'love': True, 'everything': True, 'stay': True, 'would': True, 'definately': True, 'come': True, 'back': True, 'return': True, 'area': True, 'one': True, 'recommedation': True, 'slight': True, 'improvement': True, 'breakfast': True, 'perfect': True, 'like': True, 'toast': True, 'egg': True, 'traditional': True, 'option': True, 'put': True, 'icing': True, 'cake': True}, 'Positive'), ({'staff': True, 'polite': True, 'charged': True, 'us': True, 'dollar': True, 'even': True, 'though': True, 'local': True, 'card': True, 'room': True, 'disappointing': True, 'extra': True, 'little': True, 'fridge': True, 'pool': True, 'look': True, 'dirty': True, 'feral': True, 'dog': True, 'walk': True, 'around': True, 'come': True, 'restaurant': True, 'nobody': True, 'bother': True, 'food': True, 'awful': True, 'dry': True, 'fresh': True, 'place': T ...

# %%
classifier = NaiveBayesClassifier.train(train_data)

print("Accuracy is:", classify.accuracy(classifier, test_data))

print(classifier.show_most_informative_features(10))
# Out:
# Accuracy is: 0.6875
# Most Informative Features
#                  unclean = True           Negati : Positi =     72.9 : 1.0
#                 horrible = True           Negati : Positi =     51.3 : 1.0
#                  disgust = True           Negati : Positi =     41.2 : 1.0
#                    claim = True           Negati : Positi =     41.2 : 1.0
#                     rude = True           Negati : Positi =     36.7 : 1.0
#                   booked = True           Negati : Positi =     34.9 : 1.0
#                     dirt = True           Negati : Positi =     34.9 : 1.0
#                 attitude = True           Negati : Positi =     32.3 : 1.0
#              beautifully = True           Positi : Neutra =     29.7 : 1.0
#                     unit = True           Negati : Positi =     28.5 : 1.0
# None

# %% [markdown]
# ### Single Code block

# %%
size = 1000

data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Data/booking.csv")

negative = data[(data['rating']<3)]['review_content'].dropna().tolist()[:int(size*0.3)]
neutral = data[(data['rating']>=3.5) & (data['rating']<6.5)]['review_content'].dropna().tolist()[:int(size*0.3)]
positive = data[(data['rating']>=6.5)]['review_content'].dropna().tolist()[:int(size*0.3)]

negative_tokens = [word_tokenize(text) for text in negative]
neutral_tokans = [word_tokenize(text) for text in neutral]
positive_tokens = [word_tokenize(text) for text in positive]

positive_cleaned_tokens_list = []
neutral_cleaned_tokens_list = []
negative_cleaned_tokens_list = []

for tokens in positive_tokens:
    positive_cleaned_tokens_list.append(remove_noise(tokens, stopwords.words('english')))
for tokens in neutral_tokans:
    neutral_cleaned_tokens_list.append(remove_noise(tokens, stopwords.words('english')))
for tokens in negative_tokens:
    negative_cleaned_tokens_list.append(remove_noise(tokens, stopwords.words('english')))

# all_pos_words = get_all_words(positive_cleaned_tokens_list)
# freq_dist_pos = FreqDist(all_pos_words)

positive_tokens_for_model = get_reviews_for_model(positive_cleaned_tokens_list)
neutral_tokens_for_model = get_reviews_for_model(neutral_cleaned_tokens_list)
negative_tokens_for_model = get_reviews_for_model(negative_cleaned_tokens_list)

positive_dataset = [(review_dict, "Positive") for review_dict in positive_tokens_for_model]
neutral_dataset = [(review_dict, "Neutral") for review_dict in neutral_tokens_for_model]
negative_dataset = [(review_dict, "Negative") for review_dict in negative_tokens_for_model]

dataset = positive_dataset + negative_dataset + neutral_dataset

random.shuffle(dataset)

train_data = dataset[:int(size*0.7)]
test_data = dataset[int(size*0.7):]

classifier = NaiveBayesClassifier.train(train_data)

print("Accuracy is:", classify.accuracy(classifier, test_data))
print(classifier.show_most_informative_features(10))
# Out:
# Accuracy is: 0.63
# Most Informative Features
#                 spacious = True           Positi : Negati =     20.1 : 1.0
#                  jacuzzi = True           Positi : Negati =     18.0 : 1.0
#                    dirty = True           Negati : Positi =     16.1 : 1.0
#                beautiful = True           Positi : Negati =     14.6 : 1.0
#                    suite = True           Positi : Neutra =     13.6 : 1.0
#                      bit = True           Positi : Negati =     13.0 : 1.0
#                    smell = True           Negati : Positi =     12.3 : 1.0
#                     ever = True           Negati : Neutra =     11.8 : 1.0
#                     call = True           Negati : Positi =     11.7 : 1.0
#                   always = True           Positi : Negati =     11.6 : 1.0
# None

# %% [markdown]
# # Test

# %%
# custom_tweet = "I ordered just once from TerribleCo, they screwed up, never used the app again."
custom_tweet = 'Bed was good / comfortable. Had to wit for 20 min for them to do the check in. Thay did not know that their was a booking till I showed my email.  The room given to me did not have water for a shower even. After I tolled them they offered an room change. First room I had to request  for towels and soap. Basicaly they did not any any idea of what was happaning.'

custom_tokens = remove_noise(word_tokenize(custom_tweet))

print(classifier.classify(dict([token, True] for token in custom_tokens)))
# Out:
# Negative
